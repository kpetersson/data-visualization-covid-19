# %%
import os
import pandas as pd
from scipy.optimize import curve_fit
from matplotlib import pyplot as plt
import numpy as np
import math

# %%
def exponential_model(x,a,b,c):
    return np.exp(b*(x-c))

def exponential_model_log(x,a,b,c):
    return math.log(np.exp(b*(x-c)),10)

def get_exp_fit(country):
    if country == "Iceland":
        return (0,0)
    y = df.loc[country].values
    y = np.trim_zeros(y)
    
    ones = 0
    for i in y:
        if (i == 1):
            ones += 1
            
    if ones > 3:
        y = y[ones-2:-1]
        
    if y.size < 7:
        return (0,0)
    
    x = list(range(0,y.size,1))
    ylogged = [math.log(z,10) for z in y]
    print(ylogged)
    exp_fit = curve_fit(exponential_model_log,x,ylogged,p0=[1,0.25,1])
    
    ymodel = []
    var = 0
    for i in x:
        var += ((exponential_model(i,exp_fit[0][0],exp_fit[0][1],exp_fit[0][2]) - y[i]) / exponential_model(i,exp_fit[0][0],exp_fit[0][1],exp_fit[0][2]))**2
        ymodel.append(exponential_model(i,exp_fit[0][0],exp_fit[0][1],exp_fit[0][2]))
    var /= y.size
    stddev = np.sqrt(var)
    
    return (exp_fit[0][1], stddev, x, y, ymodel)

# %%
csv = "../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv"

df = pd.read_csv(csv,index_col="Country/Region")
del df['Lat']
del df['Long']
del df['Province/State']

df = df.groupby(['Country/Region']).sum()

# %%
result = dict()
for i, j in df.iterrows():
    a = get_exp_fit(i)
    if a[0] != 0:
        result[i] = a

sorted_result = sorted(result.items(), key=lambda kv: kv[1][0])

labels = []
values = []
stddevs = []
for i in sorted_result:
    labels.append(i[0])
    values.append(((np.exp(i[1][0]))-1)*100)
    stddevs.append(i[1][1]*10)

df2 = pd.DataFrame({'x' : labels, 'y' : values, 'stderr' : stddevs})
df2.set_index("x",drop=True,inplace=True)
ax = df2.plot(kind="bar")
ax.legend([])

plt.xticks(rotation=90)
plt.grid()
plt.rcParams["figure.figsize"] = (20,10)

plt.show()
# Out:
# [0.0, 0.30102999566398114, 0.47712125471966244, 0.6020599913279623, 0.6020599913279623, 0.6020599913279623, 0.8450980400142567, 0.9542425094393249, 1.041392685158225, 1.1760912590556811, 1.2304489213782739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-04385ed4fd4e> in <module>
#       1 result = dict()
#       2 for i, j in df.iterrows():
# ----> 3     a = get_exp_fit(i)
#       4     if a[0] != 0:
#       5         result[i] = a
#
# <ipython-input-72-05d18e73793a> in get_exp_fit(country)
#      25     ylogged = [math.log(z,10) for z in y]
#      26     print(ylogged)
# ---> 27     exp_fit = curve_fit(exponential_model_log,x,ylogged,p0=[1,0.25,1])
#      28
#      29     ymodel = []
#
# c:\users\simvel\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     761         # Remove full_output from kwargs, otherwise we're passing it in twice.
#     762         return_full = kwargs.pop('full_output', False)
# --> 763         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     764         popt, pcov, infodict, errmsg, ier = res
#     765         ysize = len(infodict['fvec'])
#
# c:\users\simvel\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     386     if not isinstance(args, tuple):
#     387         args = (args,)
# --> 388     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     389     m = shape[0]
#     390
#
# c:\users\simvel\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      24 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      25                 output_shape=None):
# ---> 26     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      27     if (output_shape is not None) and (shape(res) != output_shape):
#      28         if (output_shape[0] != 1):
#
# c:\users\simvel\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\minpack.py in func_wrapped(params)
#     461     if transform is None:
#     462         def func_wrapped(params):
# --> 463             return func(xdata, *params) - ydata
#     464     elif transform.ndim == 1:
#     465         def func_wrapped(params):
#
# <ipython-input-72-05d18e73793a> in exponential_model_log(x, a, b, c)
#       3
#       4 def exponential_model_log(x,a,b,c):
# ----> 5     return math.log(np.exp(b*(x-c)))
#       6
#       7 def get_exp_fit(country):
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
fit = get_exp_fit("France")

labels = []
values = []
model = []
for i in fit[2]:
    labels.append(fit[2][i])
    values.append(fit[3][i])
    model.append(fit[4][i])

df2 = pd.DataFrame({'x' : labels, 'y' : values, 'ymodel' : model})
df2.set_index("x",drop=True,inplace=True)
ax = df2.plot()
ax.legend([])

plt.xticks(rotation=90)
plt.grid()
plt.yscale("log")
plt.rcParams["figure.figsize"] = (20,10)

plt.show()
# Out:
# c:\users\simvel\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
